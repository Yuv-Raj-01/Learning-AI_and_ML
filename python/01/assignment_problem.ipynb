# %% [markdown]
# Assignment Problems

# %% [markdown]
# Q1. Write a program that asks the user for their name and age, then prints a sentence like:<br><br>
#     "Hello Shradha, you are 21 years old!"

# %%
name = input("Please, Enter your name: ")
age = int(input("Please, Enter your age: "))
def print_name_and_age (name, age):
    print ("Hello", name," , you are",age, "years old!" )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 name = input("Please, Enter your name: ")
# ----> 2 age = int(input("Please, Enter your age: "))
#       3 def print_name_and_age (name, age):
#       4     print ("Hello", name," , you are",age, "years old!" )
#
# ValueError: invalid literal for int() with base 10: ''
