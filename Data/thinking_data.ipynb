# %% [markdown]
# # Thinking Data

# %%
import json

# %%
# load data.
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load
    return data

# %%
load_data("data1.json")
