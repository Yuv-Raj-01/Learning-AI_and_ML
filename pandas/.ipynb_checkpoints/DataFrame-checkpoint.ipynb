# %% [markdown]
# ## DataFrame

# %%
import pandas as pd

# %%
info = {
    "Name" : ["Adem","Eve","Bob"],
    "Age" : [23,24,25],
    "GPA" : [9.5,8.5,7.2]
}
df = pd.DataFrame(info)
df
# Out:
#    Name  Age  GPA
# 0  Adem   23  9.5
# 1   Eve   24  8.5
# 2   Bob   25  7.2

# %% [markdown]
# ### creating DataFrame using list of list

# %%
df2 = pd.DataFrame([["Adem",23],["Eve",24],["Bob",25]],columns = ["Name","Age"])
df2
# Out:
#    Name  Age
# 0  Adem   23
# 1   Eve   24
# 2   Bob   25
