# %% [markdown]
# ## pandas

# %%
import pandas as pd

# %% [markdown]
# ## creating DataFrame using dict

# %%
info = {
    "Name" : ["Rahul","Ram","Krishana"],
    "CGPA" : [9.5,9.6,9.1]
}

df = pd.DataFrame(info)
df
# Out:
#        Name  CGPA
# 0     Rahul   9.5
# 1       Ram   9.6
# 2  Krishana   9.1

# %% [markdown]
# ### creating series

# %% [markdown]
# ### using list

# %%
ser1 = pd.Series([1,2,3,4,5])
print(ser1)
print(ser1.iloc[2])
print(ser1.loc[2])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 3
# 3

# %%
s = pd.Series([25,26,27,28],index = ["Ram","Bob","Adem","Charlie"])
print(s)
# Out:
# Ram        25
# Bob        26
# Adem       27
# Charlie    28
# dtype: int64

# %%
print(s["Bob"])
# Out:
# 26

# %%
print(s.iloc[0])
# Out:
# 25

# %%
print(s.index)
# Out:
# Index(['Ram', 'Bob', 'Adem', 'Charlie'], dtype='str')
